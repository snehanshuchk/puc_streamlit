# %%
# !pip install torch==2.1.2 --index-url https://download.pytorch.org/whl/cpu
# !pip install transformers==4.36.2
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch==2.1.2
#   Downloading https://download.pytorch.org/whl/cpu/torch-2.1.2%2Bcpu-cp311-cp311-win_amd64.whl (194.4 MB)
#      -------------------------------------- 194.4/194.4 MB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from torch==2.1.2) (3.20.1)
# Requirement already satisfied: typing-extensions in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from torch==2.1.2) (4.15.0)
# Requirement already satisfied: sympy in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from torch==2.1.2) (1.14.0)
# Requirement already satisfied: networkx in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from torch==2.1.2) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from torch==2.1.2) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from torch==2.1.2) (2025.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch==2.1.2) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch==2.1.2) (1.3.0)
# Installing collected packages: torch
# Successfully installed torch-2.1.2+cpu
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting transformers==4.36.2
#   Downloading transformers-4.36.2-py3-none-any.whl (8.2 MB)
#      ---------------------------------------- 8.2/8.2 MB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from transformers==4.36.2) (3.20.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from transformers==4.36.2) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from transformers==4.36.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from transformers==4.36.2) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from transformers==4.36.2) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from transformers==4.36.2) (2026.1.15)
# Requirement already satisfied: requests in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from transformers==4.36.2) (2.32.5)
# Collecting tokenizers<0.19,>=0.14
#   Downloading tokenizers-0.15.2-cp311-none-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 23.2 MB/s eta 0:00:00
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from transformers==4.36.2) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from transformers==4.36.2) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36.2) (2025.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36.2) (4.15.0)
# Requirement already satisfied: colorama in c:\users\sneha\appdata\roaming\python\python311\site-packages (from tqdm>=4.27->transformers==4.36.2) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers==4.36.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers==4.36.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers==4.36.2) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers==4.36.2) (2025.11.12)
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
# Successfully installed tokenizers-0.15.2 transformers-4.36.2
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install numpy==1.26.4
# Out:
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# Installing collected packages: numpy
# Successfully installed numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.16.2 requires torch==2.1.2, which is not installed.
# ultralytics 8.0.230 requires torch>=1.8.0, which is not installed.
# ultralytics-thop 2.0.18 requires torch, which is not installed.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
#
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip uninstall -y numpy torch transformers
# Out:
# Found existing installation: numpy 2.3.5
# Uninstalling numpy-2.3.5:
#   Successfully uninstalled numpy-2.3.5
# Found existing installation: torch 2.1.2
# Uninstalling torch-2.1.2:
#   Successfully uninstalled torch-2.1.2
# Found existing installation: transformers 4.57.5
# Uninstalling transformers-4.57.5:
#   Successfully uninstalled transformers-4.57.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install streamlit sumy pandas reportlab openpyxl
# Out:
# Collecting streamlit
#   Downloading streamlit-1.53.0-py3-none-any.whl (9.1 MB)
#      ---------------------------------------- 9.1/9.1 MB 11.2 MB/s eta 0:00:00
# Collecting sumy
#   Downloading sumy-0.11.0-py2.py3-none-any.whl (97 kB)
#      ---------------------------------------- 97.3/97.3 kB ? eta 0:00:00
# Requirement already satisfied: pandas in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (2.3.3)
# Requirement already satisfied: reportlab in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (4.4.9)
# Requirement already satisfied: openpyxl in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (3.1.5)
# Collecting altair!=5.4.0,!=5.4.1,<7,>=4.0
#   Downloading altair-6.0.0-py3-none-any.whl (795 kB)
#      ------------------------------------- 795.4/795.4 kB 25.3 MB/s eta 0:00:00
# Collecting blinker<2,>=1.5.0
#   Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Collecting cachetools<7,>=5.5
#   Downloading cachetools-6.2.4-py3-none-any.whl (11 kB)
# Collecting click<9,>=7.0
#   Downloading click-8.3.1-py3-none-any.whl (108 kB)
#      -------------------------------------- 108.3/108.3 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging>=20 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (3.20.3)
# Collecting pyarrow>=7.0
#   Downloading pyarrow-23.0.0-cp311-cp311-win_amd64.whl (27.5 MB)
#      ---------------------------------------- 27.5/27.5 MB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.27 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (2.32.5)
# Collecting tenacity<10,>=8.1.0
#   Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Collecting toml<2,>=0.10.1
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (4.15.0)
# Collecting watchdog<7,>=2.1.5
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
#      ---------------------------------------- 79.1/79.1 kB 4.3 MB/s eta 0:00:00
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Downloading gitpython-3.1.46-py3-none-any.whl (208 kB)
#      ------------------------------------- 208.6/208.6 kB 12.4 MB/s eta 0:00:00
# Collecting pydeck<1,>=0.8.0b4
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#      ---------------------------------------- 6.9/6.9 MB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\sneha\appdata\roaming\python\python311\site-packages (from streamlit) (6.5.4)
# Collecting docopt<0.7,>=0.6.1
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting breadability>=0.1.20
#   Downloading breadability-0.1.20.tar.gz (32 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pycountry>=18.2.23
#   Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#      ---------------------------------------- 6.3/6.3 MB 10.6 MB/s eta 0:00:00
# Collecting nltk>=3.0.2
#   Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: charset-normalizer in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from reportlab) (3.4.4)
# Requirement already satisfied: et-xmlfile in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: jinja2 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Collecting jsonschema>=3.0
#   Downloading jsonschema-4.26.0-py3-none-any.whl (90 kB)
#      ---------------------------------------- 90.6/90.6 kB ? eta 0:00:00
# Collecting narwhals>=1.27.1
#   Downloading narwhals-2.15.0-py3-none-any.whl (432 kB)
#      ------------------------------------- 432.9/432.9 kB 28.2 MB/s eta 0:00:00
# Collecting chardet
#   Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#      ------------------------------------- 199.4/199.4 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=2.0 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from breadability>=0.1.20->sumy) (6.0.2)
# Requirement already satisfied: colorama in c:\users\sneha\appdata\roaming\python\python311\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.8/62.8 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: joblib in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.0.2->sumy) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.0.2->sumy) (2026.1.15)
# Requirement already satisfied: tqdm in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.0.2->sumy) (4.67.1)
# Requirement already satisfied: six>=1.5 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.11.12)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sneha\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2025.9.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.37.0-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.25.0
#   Downloading rpds_py-0.30.0-cp311-cp311-win_amd64.whl (236 kB)
#      ---------------------------------------- 236.0/236.0 kB ? eta 0:00:00
# Installing collected packages: docopt, watchdog, toml, tenacity, smmap, rpds-py, pycountry, pyarrow, narwhals, click, chardet, cachetools, blinker, referencing, pydeck, nltk, gitdb, breadability, sumy, jsonschema-specifications, gitpython, jsonschema, altair, streamlit
#   Running setup.py install for docopt: started
#   Running setup.py install for docopt: finished with status 'done'
#   Running setup.py install for breadability: started
#   Running setup.py install for breadability: finished with status 'done'
# Successfully installed altair-6.0.0 blinker-1.9.0 breadability-0.1.20 cachetools-6.2.4 chardet-5.2.0 click-8.3.1 docopt-0.6.2 gitdb-4.0.12 gitpython-3.1.46 jsonschema-4.26.0 jsonschema-specifications-2025.9.1 narwhals-2.15.0 nltk-3.9.2 pyarrow-23.0.0 pycountry-24.6.1 pydeck-0.9.1 referencing-0.37.0 rpds-py-0.30.0 smmap-5.0.2 streamlit-1.53.0 sumy-0.11.0 tenacity-9.1.2 toml-0.10.2 watchdog-6.0.0
#   DEPRECATION: docopt is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   DEPRECATION: breadability is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
